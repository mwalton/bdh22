# %%
import psycopg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# # Relavant Tables
# Procedure timeseries mimic III tables that could be used in critical care pathway discovery and modelling
#
# - [procedures_icd](https://mimic.physionet.org/mimictables/procedures_icd/): (240,095) Contains ICD procedures for patients, most notably ICD-9 procedures
#     - links to [d_icd_procedures](https://mimic.physionet.org/mimictables/d_icd_procedures/) (3,882) on ICD9_CODE
# - [chartevents](https://mimic.physionet.org/mimictables/chartevents/): (330,712,483) all data for all patients
# - [cptevents](https://mimic.physionet.org/mimictables/cptevents/): (573146) Contains current procedural terminology (CPT) codes, which facilitate billing for procedures performed on patients.
# - [procedureevents_mv](https://mimic.physionet.org/mimictables/procedureevents_mv/): (258,066) Contains procedures for patients
# - [labevents](https://mimic.physionet.org/mimictables/labevents/): (27,854,055) Contains all laboratory measurements for a given patient, including out patient data.
# - [noteevents](https://mimic.physionet.org/mimictables/noteevents/): (2,083,180) Contains all notes for patients.

# %% [markdown]
# # PROCEDURES_ICD Analysis

# %%
sqluser = 'mwalton'
dbname = 'mimic'
schema_name = 'mimiciii'

connection = psycopg2.connect(dbname=dbname, user=sqluser)
cursor = connection.cursor()
cursor.execute('SET search_path to {}'.format(schema_name))

query = '''SELECT subject_id, hadm_id, seq_num, procedures_icd.icd9_code, d_icd_procedures.short_title, d_icd_procedures.long_title
        FROM procedures_icd
        LEFT OUTER JOIN d_icd_procedures ON (procedures_icd.icd9_code = d_icd_procedures.icd9_code)
        '''

procedures = pd.read_sql_query(query, connection)
procedures_seq = procedures.set_index(['subject_id','hadm_id', 'seq_num'])

# %%
procedures_seq
# Out:
#                            icd9_code               short_title  \
# subject_id hadm_id seq_num
# 62641      154460  3            3404   Insert intercostal cath
# 2592       130856  1            9671  Cont inv mec ven <96 hrs
#                    2            3893           Venous cath NEC
# 55357      119355  1            9672  Cont inv mec ven 96+ hrs
#                    2            0331                Spinal tap
#                    3            3893           Venous cath NEC
# 9545       158060  1             034  Excis spinal cord lesion
# 28600      189217  1            3613  Aortocor bypas-3 cor art
#                    2            3615  1 int mam-cor art bypass
#                    3            3961   Extracorporeal circulat
# 16994      115444  1            3601                      None
#                    2            3606   Ins nondrug elut cor st
#                    3            3723   Rt/left heart card cath
#                    4            8856  Coronar arteriogr-2 cath
#                    5            9671  Cont inv mec ven <96 hrs
#                    6            9915   Parent infus nutrit sub
# 13579      186290  1            3612  Aortocor bypas-2 cor art
#                    2            3615  1 int mam-cor art bypass
#                    3            3961   Extracorporeal circulat
#                    4            3723   Rt/left heart card cath
#                    5            8856  Coronar arteriogr-2 cath
#                    6            8853  Lt heart angiocardiogram
# 18395      101133  1            0159      Other brain excision
# 9090       140708  1            4399     Total gastrectomy NEC
#                    2            4254  Thorac esophagoenter NEC
#                    3            4413           Gastroscopy NEC
#                    4            4639           Enterostomy NEC
# 18649      109107  1            4562  Part sm bowel resect NEC
#                    2            4651    Sm bowel stoma closure
#                    3            9915   Parent infus nutrit sub
# ...                              ...                       ...
# 84107      137690  3             966   Entral infus nutrit sub
#                    4            3893           Venous cath NEC
# 41035      102460  1            3228   Endosc destruc lung les
#                    2            3201  Endosc destruc bronc les
# 51301      193117  1            0066                      PTCA
#                    2            3606   Ins nondrug elut cor st
#                    3            0045   Insert 1 vascular stent
#                    4            0040      Procedure-one vessel
#                    5            8856  Coronar arteriogr-2 cath
#                    6            3893           Venous cath NEC
#                    7            3891  Arterial catheterization
#                    8            9920  Inj/inf platelet inhibit
# 96777      176399  1            9914  Injct/inf immunoglobulin
#                    2            9915   Parent infus nutrit sub
#                    3            3324   Closed bronchial biopsy
# 77242      130340  1            3897  CV cath plcmt w guidance
#                    2            3897  CV cath plcmt w guidance
# 42694      180323  1            0206   Cranial osteoplasty NEC
#                    2            0123    Reopen craniotomy site
#                    3            9912      Allergy immunization
# 51519      169041  1            0159      Other brain excision
# 67415      150871  1            3523  Opn/oth rep mtrl vlv-tis
#                    2            3733  Exc/dest hrt lesion open
#                    3            3961   Extracorporeal circulat
#                    4            3727           Cardiac mapping
#                    5            3736    Exc,destrct,exclus LAA
#                    6            3893           Venous cath NEC
#                    7            8872       Dx ultrasound-heart
#                    8            3893           Venous cath NEC
#                    9            3722   Left heart cardiac cath
#
#                                                                    long_title
# subject_id hadm_id seq_num
# 62641      154460  3           Insertion of intercostal catheter for drainage
# 2592       130856  1        Continuous invasive mechanical ventilation for...
#                    2         Venous catheterization, not elsewhere classified
# 55357      119355  1        Continuous invasive mechanical ventilation for...
#                    2                                               Spinal tap
#                    3         Venous catheterization, not elsewhere classified
# 9545       158060  1        Excision or destruction of lesion of spinal co...
# 28600      189217  1        (Aorto)coronary bypass of three coronary arteries
#                    2           Single internal mammary-coronary artery bypass
#                    3        Extracorporeal circulation auxiliary to open h...
# 16994      115444  1                                                     None
#                    2        Insertion of non-drug-eluting coronary artery ...
#                    3        Combined right and left heart cardiac catheter...
#                    4               Coronary arteriography using two catheters
#                    5        Continuous invasive mechanical ventilation for...
#                    6        Parenteral infusion of concentrated nutritiona...
# 13579      186290  1          (Aorto)coronary bypass of two coronary arteries
#                    2           Single internal mammary-coronary artery bypass
#                    3        Extracorporeal circulation auxiliary to open h...
#                    4        Combined right and left heart cardiac catheter...
#                    5               Coronary arteriography using two catheters
#                    6               Angiocardiography of left heart structures
# 18395      101133  1        Other excision or destruction of lesion or tis...
# 9090       140708  1                                  Other total gastrectomy
#                    2                  Other intrathoracic esophagoenterostomy
#                    3                                        Other gastroscopy
#                    4                                        Other enterostomy
# 18649      109107  1               Other partial resection of small intestine
#                    2                      Closure of stoma of small intestine
#                    3        Parenteral infusion of concentrated nutritiona...
# ...                                                                       ...
# 84107      137690  3        Enteral infusion of concentrated nutritional s...
#                    4         Venous catheterization, not elsewhere classified
# 41035      102460  1        Endoscopic excision or destruction of lesion o...
#                    2        Endoscopic excision or destruction of lesion o...
# 51301      193117  1        Percutaneous transluminal coronary angioplasty...
#                    2        Insertion of non-drug-eluting coronary artery ...
#                    3                          Insertion of one vascular stent
#                    4                               Procedure on single vessel
#                    5               Coronary arteriography using two catheters
#                    6         Venous catheterization, not elsewhere classified
#                    7                                 Arterial catheterization
#                    8              Injection or infusion of platelet inhibitor
# 96777      176399  1                  Injection or infusion of immunoglobulin
#                    2        Parenteral infusion of concentrated nutritiona...
#                    3                   Closed [endoscopic] biopsy of bronchus
# 77242      130340  1          Central venous catheter placement with guidance
#                    2          Central venous catheter placement with guidance
# 42694      180323  1                                Other cranial osteoplasty
#                    2                             Reopening of craniotomy site
#                    3                                 Immunization for allergy
# 51519      169041  1        Other excision or destruction of lesion or tis...
# 67415      150871  1        Open and other replacement of mitral valve wit...
#                    2        Excision or destruction of other lesion or tis...
#                    3        Extracorporeal circulation auxiliary to open h...
#                    4                                          Cardiac mapping
#                    5        Excision, destruction, or exclusion of left at...
#                    6         Venous catheterization, not elsewhere classified
#                    7                           Diagnostic ultrasound of heart
#                    8         Venous catheterization, not elsewhere classified
#                    9                       Left heart cardiac catheterization
#
# [240095 rows x 3 columns]

# %%
procedures['seq_num'].hist()

# %%
counts = pd.value_counts(procedures['icd9_code'])

# %%
counts.max()
# Out:
# 14731
